# %%
import pandas as pd
import sqlite3 as sql

# %%
database = 'jobs.db'
conn = sql.connect(database)

# %%
pd.read_sql_query('select * from sqlite_master',conn)
# Out:
#     type                   name      tbl_name  rootpage  \
# 0  table           recent_grads  recent_grads         2
# 1  index  ix_recent_grads_index  recent_grads         3
#
#                                                  sql
# 0  CREATE TABLE "recent_grads" (\n"index" INTEGER...
# 1  CREATE INDEX "ix_recent_grads_index"ON "recent...

# %%
q = """
select * from recent_grads
"""
pd.read_sql_query(q,conn)
# Out:
#      index  Rank  Major_code                                      Major  \
# 0        0     1        2419                      PETROLEUM ENGINEERING
# 1        1     2        2416             MINING AND MINERAL ENGINEERING
# 2        2     3        2415                  METALLURGICAL ENGINEERING
# 3        3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4        4     5        2405                       CHEMICAL ENGINEERING
# ..     ...   ...         ...                                        ...
# 168    168   169        3609                                    ZOOLOGY
# 169    169   170        5201                     EDUCATIONAL PSYCHOLOGY
# 170    170   171        5202                        CLINICAL PSYCHOLOGY
# 171    171   172        5203                      COUNSELING PSYCHOLOGY
# 172    172   173        3501                            LIBRARY SCIENCE
#
#                Major_category  Total  Sample_size    Men  Women  ShareWomen  \
# ...

# %%
q = """select Major from recent_grads"""
pd.read_sql_query(q,conn)
# Out:
#                                          Major
# 0                        PETROLEUM ENGINEERING
# 1               MINING AND MINERAL ENGINEERING
# 2                    METALLURGICAL ENGINEERING
# 3    NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4                         CHEMICAL ENGINEERING
# ..                                         ...
# 168                                    ZOOLOGY
# 169                     EDUCATIONAL PSYCHOLOGY
# 170                        CLINICAL PSYCHOLOGY
# 171                      COUNSELING PSYCHOLOGY
# 172                            LIBRARY SCIENCE
#
# [173 rows x 1 columns]

# %%
q = "select Rank, Major from recent_grads"
pd.read_sql_query(q,conn)
# Out:
#      Rank                                      Major
# 0       1                      PETROLEUM ENGINEERING
# 1       2             MINING AND MINERAL ENGINEERING
# 2       3                  METALLURGICAL ENGINEERING
# 3       4  NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4       5                       CHEMICAL ENGINEERING
# ..    ...                                        ...
# 168   169                                    ZOOLOGY
# 169   170                     EDUCATIONAL PSYCHOLOGY
# 170   171                        CLINICAL PSYCHOLOGY
# 171   172                      COUNSELING PSYCHOLOGY
# 172   173                            LIBRARY SCIENCE
#
# [173 rows x 2 columns]

# %%
pd.read_sql_query("""select * from recent_grads""",conn)
# Out:
#      index  Rank  Major_code                                      Major  \
# 0        0     1        2419                      PETROLEUM ENGINEERING
# 1        1     2        2416             MINING AND MINERAL ENGINEERING
# 2        2     3        2415                  METALLURGICAL ENGINEERING
# 3        3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4        4     5        2405                       CHEMICAL ENGINEERING
# ..     ...   ...         ...                                        ...
# 168    168   169        3609                                    ZOOLOGY
# 169    169   170        5201                     EDUCATIONAL PSYCHOLOGY
# 170    170   171        5202                        CLINICAL PSYCHOLOGY
# 171    171   172        5203                      COUNSELING PSYCHOLOGY
# 172    172   173        3501                            LIBRARY SCIENCE
#
#                Major_category  Total  Sample_size    Men  Women  ShareWomen  \
# ...

# %%
q = """
select Major,Major_category , ShareWomen from recent_grads 
where ShareWomen > 0.5 or (Major_category== 'Engineering' and ShareWomen <=0.5)

"""
pd.read_sql_query(q,conn)
# Out:
#                                          Major            Major_category  \
# 0                        PETROLEUM ENGINEERING               Engineering
# 1               MINING AND MINERAL ENGINEERING               Engineering
# 2                    METALLURGICAL ENGINEERING               Engineering
# 3    NAVAL ARCHITECTURE AND MARINE ENGINEERING               Engineering
# 4                         CHEMICAL ENGINEERING               Engineering
# ..                                         ...                       ...
# 119                                    ZOOLOGY    Biology & Life Science
# 120                     EDUCATIONAL PSYCHOLOGY  Psychology & Social Work
# 121                        CLINICAL PSYCHOLOGY  Psychology & Social Work
# 122                      COUNSELING PSYCHOLOGY  Psychology & Social Work
# 123                            LIBRARY SCIENCE                 Education
#
#      ShareWomen
# 0      0.120564
# 1      0.101852
# 2      0.153037
# 3      0.107313
# ...

# %%
q = """
select Major, Major_category, ShareWomen from recent_grads 
where ShareWomen > 0.5 or (Major_category =='Engineering' and ShareWomen <=0.5)
order by ShareWomen DESC
"""
pd.read_sql_query(q,conn)
# Out:
#                                          Major  \
# 0                  ANTHROPOLOGY AND ARCHEOLOGY
# 1                    EARLY CHILDHOOD EDUCATION
# 2             MATHEMATICS AND COMPUTER SCIENCE
# 3                         ELEMENTARY EDUCATION
# 4                              ANIMAL SCIENCES
# ..                                         ...
# 119                     BIOMEDICAL ENGINEERING
# 120  NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 121             MINING AND MINERAL ENGINEERING
# 122                   ENGINEERING TECHNOLOGIES
# 123     MISCELLANEOUS ENGINEERING TECHNOLOGIES
#
#                       Major_category  ShareWomen
# 0          Humanities & Liberal Arts    0.968954
# 1                          Education    0.967998
# 2            Computers & Mathematics    0.927807
# 3                          Education    0.923745
# 4    Agriculture & Natural Resources    0.910933
# ..                               ...         ...
# ...

# %%
q = """
select count(ShareWomen) from recent_grads
where ShareWomen > 0.5
"""
pd.read_sql_query(q,conn)
# Out:
#    count(ShareWomen)
# 0                 97

# %%
def read(q):
    return pd.read_sql_query(q,conn)

# %%
read("""
select * from recent_grads
""")
# Out:
#      index  Rank  Major_code                                      Major  \
# 0        0     1        2419                      PETROLEUM ENGINEERING
# 1        1     2        2416             MINING AND MINERAL ENGINEERING
# 2        2     3        2415                  METALLURGICAL ENGINEERING
# 3        3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4        4     5        2405                       CHEMICAL ENGINEERING
# ..     ...   ...         ...                                        ...
# 168    168   169        3609                                    ZOOLOGY
# 169    169   170        5201                     EDUCATIONAL PSYCHOLOGY
# 170    170   171        5202                        CLINICAL PSYCHOLOGY
# 171    171   172        5203                      COUNSELING PSYCHOLOGY
# 172    172   173        3501                            LIBRARY SCIENCE
#
#                Major_category  Total  Sample_size    Men  Women  ShareWomen  \
# ...

# %%
read("""
select count(Major_category) from recent_grads
where Major_Category == "Engineering"
""")
# Out:
#    count(Major_category)
# 0                     29

# %%
read("""
select Major_category , count(Major_category) Num_fields from recent_grads 
where Major_category !=  "Social Science"
group by Major_category
""")
# Out:
#                          Major_category  Num_fields
# 0       Agriculture & Natural Resources          10
# 1                                  Arts           8
# 2                Biology & Life Science          14
# 3                              Business          13
# 4           Communications & Journalism           4
# 5               Computers & Mathematics          11
# 6                             Education          16
# 7                           Engineering          29
# 8                                Health          12
# 9             Humanities & Liberal Arts          15
# 10  Industrial Arts & Consumer Services           7
# 11                    Interdisciplinary           1
# 12                  Law & Public Policy           5
# 13                    Physical Sciences          10
# 14             Psychology & Social Work           9

# %%
read("""
select Major_category , count(Major_category) num_field from recent_grads 
where Major_category != 'Social Science'
group by Major_category
""")
# Out:
#                          Major_category  num_field
# 0       Agriculture & Natural Resources         10
# 1                                  Arts          8
# 2                Biology & Life Science         14
# 3                              Business         13
# 4           Communications & Journalism          4
# 5               Computers & Mathematics         11
# 6                             Education         16
# 7                           Engineering         29
# 8                                Health         12
# 9             Humanities & Liberal Arts         15
# 10  Industrial Arts & Consumer Services          7
# 11                    Interdisciplinary          1
# 12                  Law & Public Policy          5
# 13                    Physical Sciences         10
# 14             Psychology & Social Work          9

# %%
read("""
select Major_category, avg(ShareWomen) from recent_grads
group by Major_category
""")
# Out:
#                          Major_category  avg(ShareWomen)
# 0       Agriculture & Natural Resources         0.617938
# 1                                  Arts         0.561851
# 2                Biology & Life Science         0.584518
# 3                              Business         0.405063
# 4           Communications & Journalism         0.643835
# 5               Computers & Mathematics         0.512752
# 6                             Education         0.674986
# 7                           Engineering         0.257158
# 8                                Health         0.616857
# 9             Humanities & Liberal Arts         0.676193
# 10  Industrial Arts & Consumer Services         0.449351
# 11                    Interdisciplinary         0.495397
# 12                  Law & Public Policy         0.335990
# 13                    Physical Sciences         0.508749
# 14             Psychology & Social Work         0.777763
# ...
